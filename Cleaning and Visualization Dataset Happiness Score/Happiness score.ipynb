# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

# %%
# La siguiente línea es para ver las imagenes dentro del notebook
# %matplotlib inline

# %%
felicidad = pd.read_csv('2016.csv',delimiter=';')

print('Dataset Felicidad: \n')
felicidad
# Out:
# Dataset Felicidad:
#          Country                           Region  HappinessRank  \
# 0        Denmark                   Western Europe              1
# 1    Switzerland                   Western Europe              2
# 2        Iceland                   Western Europe              3
# 3         Norway                   Western Europe              4
# 4        Finland                   Western Europe              5
# ..           ...                              ...            ...
# 152        Benin               Sub-Saharan Africa            153
# 153  Afghanistan                    Southern Asia            154
# 154         Togo               Sub-Saharan Africa            155
# 155        Syria  Middle East and Northern Africa            156
# 156      Burundi               Sub-Saharan Africa            157
#
#      HappinessScore  Lower Confidence Interval  Upper Confidence Interval  \
# 0             7.526                      7.460                      7.592
# 1             7.509                      7.428                      7.590
# 2             7.501                      7.333                      7.669
# 3             7.498                      7.421                      7.575
# 4             7.413                      7.351                      7.475
# ..              ...                        ...                        ...
# 152           3.484                      3.404                      3.564
# 153           3.360                      3.288                      3.432
# 154           3.303                      3.192                      3.414
# 155           3.069                      2.936                      3.202
# 156           2.905                      2.732                      3.078
#
#        Economy     Family   Health  Freedom  Trust (Government Corruption)  \
# 0    144.17800  116.37400  0.79504  0.57941                        0.44453
# 1    152.73300  114.52400  0.86303  0.58557                        0.41203
# 2    142.66600  118.32600  0.86733  0.56624                        0.14975
# 3    157.74400   11.26900  0.79579  0.59609                        0.35776
# 4    140.59800  113.46400  0.81091  0.57104                        0.41004
# ..         ...        ...      ...      ...                            ...
# 152    0.39499    0.10419  0.21028  0.39747                        0.06681
# 153    0.38227    0.11037  0.17344  0.16430                        0.07112
# 154    0.28123    0.00000  0.24811  0.34678                        0.11587
# 155    0.74719    0.14866  0.62994  0.06912                        0.17233
# 156    0.06831    0.23442  0.15747  0.04320                        0.09419
#
#      Generosity  Dystopia Residual
# 0       0.36171          273.93900
# 1       0.28083          269.46300
# 2       0.47678          283.13700
# 3       0.37895          266.46500
# 4       0.25492          282.59600
# ..          ...                ...
# 152     0.20180          210.81200
# 153     0.31268          214.55800
# 154     0.17517           21.35400
# 155     0.48397            0.81789
# 156     0.20290          210.40400
#
# [157 rows x 13 columns]

# %%
print('Dataset Felicidad Info: \n')
felicidad.info()
# Out:
# Dataset Felicidad Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
# Country                          157 non-null object
# Region                           157 non-null object
# HappinessRank                    157 non-null int64
# HappinessScore                   157 non-null float64
# Lower Confidence Interval        157 non-null float64
# Upper Confidence Interval        157 non-null float64
# Economy                          157 non-null float64
# Family                           157 non-null float64
# Health                           157 non-null float64
# Freedom                          157 non-null float64
# Trust (Government Corruption)    157 non-null float64
# Generosity                       157 non-null float64
# Dystopia Residual                157 non-null float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 16.1+ KB

# %%
print('Dataset Felicidad Describe: \n')

felicidad.describe()
# Out:
# Dataset Felicidad Describe:
#        HappinessRank  HappinessScore  Lower Confidence Interval  \
# count     157.000000      157.000000                 157.000000
# mean       78.980892        5.382185                   5.282395
# std        45.466030        1.141674                   1.148043
# min         1.000000        2.905000                   2.732000
# 25%        40.000000        4.404000                   4.327000
# 50%        79.000000        5.314000                   5.237000
# 75%       118.000000        6.269000                   6.154000
# max       157.000000        7.526000                   7.460000
#
#        Upper Confidence Interval     Economy      Family      Health  \
# count                 157.000000  157.000000  157.000000  157.000000
# mean                    5.481975   61.769763   28.059181    0.557619
# std                     1.136493   65.187857   46.579948    0.229349
# min                     3.078000    0.000000    0.000000    0.000000
# 25%                     4.465000    0.670240    0.641840    0.382910
# 50%                     5.419000   10.893000    0.841420    0.596590
# 75%                     6.434000  127.607000  100.508000    0.729930
# max                     7.669000  182.427000  118.326000    0.952770
#
#           Freedom  Trust (Government Corruption)  Generosity  \
# count  157.000000                     157.000000  157.000000
# mean     0.370994                       0.137624    0.242635
# std      0.145507                       0.111038    0.133756
# min      0.000000                       0.000000    0.000000
# 25%      0.257480                       0.061260    0.154570
# 50%      0.397470                       0.105470    0.222450
# 75%      0.484530                       0.175540    0.311850
# max      0.608480                       0.505210    0.819710
#
#        Dystopia Residual
# count         157.000000
# mean          214.750404
# std            81.963229
# min             0.817890
# 25%           195.473000
# 50%           225.531000
# 75%           265.614000
# max           383.772000

# %%
print('Cantidad de Países por Región: \n')
felicidad.Region.value_counts()
# Out:
# Cantidad de Países por Región:
# Sub-Saharan Africa                 38
# Central and Eastern Europe         29
# Latin America and Caribbean        24
# Western Europe                     21
# Middle East and Northern Africa    19
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
print('Correlación entre valores del Dataset Felicidad: \n')
felicidad.corr()
# Out:
# Correlación entre valores del Dataset Felicidad:
#                                HappinessRank  HappinessScore  \
# HappinessRank                       1.000000       -0.995743
# HappinessScore                     -0.995743        1.000000
# Lower Confidence Interval          -0.994928        0.999485
# Upper Confidence Interval          -0.995525        0.999474
# Economy                            -0.710447        0.708389
# Family                             -0.588647        0.591152
# Health                             -0.767991        0.765384
# Freedom                            -0.557169        0.566827
# Trust (Government Corruption)      -0.387102        0.402032
# Generosity                         -0.145369        0.156848
# Dystopia Residual                  -0.397696        0.397397
#
#                                Lower Confidence Interval  \
# HappinessRank                                  -0.994928
# HappinessScore                                  0.999485
# Lower Confidence Interval                       1.000000
# Upper Confidence Interval                       0.997919
# Economy                                         0.708909
# Family                                          0.595968
# Health                                          0.769177
# Freedom                                         0.566857
# Trust (Government Corruption)                   0.404840
# Generosity                                      0.158025
# Dystopia Residual                               0.394164
#
#                                Upper Confidence Interval   Economy    Family  \
# HappinessRank                                  -0.995525 -0.710447 -0.588647
# HappinessScore                                  0.999474  0.708389  0.591152
# Lower Confidence Interval                       0.997919  0.708909  0.595968
# Upper Confidence Interval                       1.000000  0.707122  0.585669
# Economy                                         0.707122  1.000000  0.505921
# Family                                          0.585669  0.505921  1.000000
# Health                                          0.760752  0.672511  0.484613
# Freedom                                         0.566203  0.335910  0.336468
# Trust (Government Corruption)                   0.398775  0.354125  0.237864
# Generosity                                      0.155495 -0.016836  0.101832
# Dystopia Residual                               0.400247  0.121302  0.087549
#
#                                  Health   Freedom  \
# HappinessRank                 -0.767991 -0.557169
# HappinessScore                 0.765384  0.566827
# Lower Confidence Interval      0.769177  0.566857
# Upper Confidence Interval      0.760752  0.566203
# Economy                        0.672511  0.335910
# Family                         0.484613  0.336468
# Health                         1.000000  0.341199
# Freedom                        0.341199  1.000000
# Trust (Government Corruption)  0.249583  0.502054
# Generosity                     0.075987  0.361751
# Dystopia Residual              0.105088 -0.003854
#
#                                Trust (Government Corruption)  Generosity  \
# HappinessRank                                      -0.387102   -0.145369
# HappinessScore                                      0.402032    0.156848
# Lower Confidence Interval                           0.404840    0.158025
# Upper Confidence Interval                           0.398775    0.155495
# Economy                                             0.354125   -0.016836
# Family                                              0.237864    0.101832
# Health                                              0.249583    0.075987
# Freedom                                             0.502054    0.361751
# Trust (Government Corruption)                       1.000000    0.305930
# Generosity                                          0.305930    1.000000
# Dystopia Residual                                  -0.020732   -0.127979
#
#                                Dystopia Residual
# HappinessRank                          -0.397696
# HappinessScore                          0.397397
# Lower Confidence Interval               0.394164
# Upper Confidence Interval               0.400247
# Economy                                 0.121302
# Family                                  0.087549
# Health                                  0.105088
# Freedom                                -0.003854
# Trust (Government Corruption)          -0.020732
# Generosity                             -0.127979
# Dystopia Residual                       1.000000

# %%
print('Correlación entre valores del Dataset Felicidad: \n')
fe=felicidad.loc[:,['HappinessScore','Family','Economy','Health','Freedom']]
fecorr= fe.corr()
fecorr
# Out:
# Correlación entre valores del Dataset Felicidad:
#                 HappinessScore    Family   Economy    Health   Freedom
# HappinessScore        1.000000  0.591152  0.708389  0.765384  0.566827
# Family                0.591152  1.000000  0.505921  0.484613  0.336468
# Economy               0.708389  0.505921  1.000000  0.672511  0.335910
# Health                0.765384  0.484613  0.672511  1.000000  0.341199
# Freedom               0.566827  0.336468  0.335910  0.341199  1.000000

# %%
print('Gráfico Correlación entre valores del Dataset Felicidad: \n')

plt.rcParams['figure.figsize'] = (12,10)
# Seteamos opciones de pandas sobre las columnas y su ancho
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)

sns.heatmap(fecorr, xticklabels=fecorr.columns, yticklabels=fecorr.columns);
# Out:
# Gráfico Correlación entre valores del Dataset Felicidad:

# %%
print('Promedio de Happiness Score por Región: \n')
f= felicidad.groupby('Region')['HappinessScore'].mean().reset_index()
print(str(f.HappinessScore.sum()))
f.sort_values(by='HappinessScore')
# Out:
# Promedio de Happiness Score por Región:
#
# 57.78442127589087
#                             Region  HappinessScore
# 8               Sub-Saharan Africa        4.136421
# 7                    Southern Asia        4.563286
# 6                Southeastern Asia        5.338889
# 1       Central and Eastern Europe        5.370690
# 4  Middle East and Northern Africa        5.386053
# 2                     Eastern Asia        5.624167
# 3      Latin America and Caribbean        6.101750
# 9                   Western Europe        6.685667
# 5                    North America        7.254000
# 0        Australia and New Zealand        7.323500

# %%
masFeliz = f.Region.iloc[f.sort_values(by='HappinessScore').tail(1).index].values

print('La region más feliz considerando el promedio de HS de sus paises es: ' + str(masFeliz))
# Out:
# La region más feliz considerando el promedio de HS de sus paises es: ['Australia and New Zealand']

# %%
menosFeliz = f.Region.iloc[f.sort_values(by='HappinessScore').head(1).index].values

print('La region menos feliz considerando el promedio de HS de sus paises es: ' + str(menosFeliz))
# Out:
# La region menos feliz considerando el promedio de HS de sus paises es: ['Sub-Saharan Africa']

# %%
print('Gráfico de barras Happiness Score por Región: \n')

f.sort_values(by='HappinessScore',ascending=False,inplace=True)

plt.rcParams['figure.figsize'] = (12,8)


pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)

a=sns.barplot(x='Region', y='HappinessScore',palette='pastel',data=f)
a.set_xlabel("Region",fontsize=16)
a.set_ylabel("Happiness Score",fontsize=16)
a.set_title("Promedio de Happiness Score por Region \n", fontsize=18)
plt.xticks(rotation=65);
# Out:
# Gráfico de barras Happiness Score por Región:

# %%
print('Gráfico de Torta % de HS por Región: \n')

# Acá configuramos el tamaño de las figuras
plt.rcParams['figure.figsize'] = (12,8)
# Seteamos opciones de pandas sobre las columnas y su ancho
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)

f.plot(x='Region',y='HappinessScore', kind='pie',startangle=20,autopct='%1.2f%%',colormap='Pastel1',title='Porcentaje de HS por Región');
plt.legend(f['Region'],title='Happiness Score por Región \n',bbox_to_anchor=(1.10, 0.5));

#loc='lower right',
#g.ax.legend(loc='center right', bbox_to_anchor=(1.00, 0.3), ncol=1)
# Out:
# Gráfico de Torta % de HS por Región:

# %%
print('Gráfico de Economía de los países de la Región Australia and New Zealand: \n')

plt.rcParams['figure.figsize'] = (8,6)

fe_Aus_Nz=felicidad[felicidad.Region == 'Australia and New Zealand'].copy()
fe_Aus_Nz.sort_values(by='Economy',ascending=False,inplace=True)

fe_Aus_Nz.plot(x='Country',y='Economy', kind='bar',title='Economy Region: Australia and New Zealand',grid=True,colormap='Pastel1')
plt.legend(fe_Aus_Nz['Country'],loc='lower right',title='Economy Region: Australia and New Zealand  \n')
plt.xticks(rotation='horizontal');
# Out:
# Gráfico de Economía de los países de la Región Australia and New Zealand:

# %%
print('Gráfico de Economía de los países de la Región North America: \n')

plt.rcParams['figure.figsize'] = (8,6)


fe_Na=felicidad[felicidad.Region == 'North America'].copy()
fe_Na.sort_values(by='Economy',ascending=False,inplace=True)


fe_Na.plot(x='Country',y='Economy', kind='bar',title='Economy Region: North America',grid=True,colormap='Pastel1')
plt.legend(fe_Na['Country'],loc='lower right',title='Economy Region: North America  \n')
plt.xticks(rotation='horizontal');
# Out:
# Gráfico de Economía de los países de la Región North America:

# %%
print('Gráfico de Economía de los países de la Región Latin America and Caribbean: \n')

plt.rcParams['figure.figsize'] = (12,8)


fe_La=felicidad[felicidad.Region == 'Latin America and Caribbean'].copy()
fe_La.sort_values(by='Economy',ascending=False,inplace=True)


fe_La.plot(x='Country',y='Economy', kind='bar',title='Economy Region: Latin America and Caribbean',grid=True,colormap='Pastel1')
plt.legend(fe_La['Country'],loc='lower right',title='Economy Region: Latin America and Caribbean  \n')
plt.xticks(rotation='vertical');
# Out:
# Gráfico de Economía de los países de la Región Latin America and Caribbean:

# %%
print('Gráfico de Familia de los países de la Región Latin America and Caribbean: \n')

plt.rcParams['figure.figsize'] = (12,8)

fe_La.sort_values(by='Family',ascending=False,inplace=True)


fe_La.plot(x='Country',y='Family', kind='bar',title='Family Region: Latin America and Caribbean',grid=True,colormap='Pastel2')
plt.legend(fe_La['Country'],loc='lower right',title='Family Region: Latin America and Caribbean  \n');
# Out:
# Gráfico de Familia de los países de la Región Latin America and Caribbean:

# %%
felicidadMaxima=felicidad[felicidad['HappinessScore']==felicidad.HappinessScore.max()]
print('Valores del País con mayor Felicidad vs mayores Valores: \n')
print('Economy: '+ str(felicidadMaxima.Economy.values) + ' Mayor valor:  '+ str(felicidad.Economy.max()))
print('Family: '+ str(felicidadMaxima.Family.values) + ' Mayor valor:  '+ str(felicidad.Family.max()) )
print('Health: '+ str(felicidadMaxima.Health.values) + ' Mayor valor:  '+ str(felicidad.Health.max()))
print('Freedom: '+ str(felicidadMaxima.Freedom.values) + ' Mayor valor:  '+ str(felicidad.Freedom.max()))
# Out:
# Valores del País con mayor Felicidad vs mayores Valores:
#
# Economy: [144.178] Mayor valor:  182.42700000000002
# Family: [116.374] Mayor valor:  118.32600000000001
# Health: [0.79504] Mayor valor:  0.9527700000000001
# Freedom: [0.57941] Mayor valor:  0.60848

# %%
#TOP 5 de valores de mayor economía
print('Mayores 5 valores de Economía: \n')

fel=felicidad.iloc[felicidad.Economy.sort_values(ascending=False).head(5).index]
fel.loc[:,['Region','Country','Economy']]
# Out:
# Mayores 5 valores de Economía:
#                              Region     Country  Economy
# 35  Middle East and Northern Africa       Qatar  182.427
# 19                   Western Europe  Luxembourg  169.752
# 21                Southeastern Asia   Singapore  164.555
# 40  Middle East and Northern Africa      Kuwait  161.714
# 3                    Western Europe      Norway  157.744

# %%
print('Gráfico de Economía/Happiness Score por País \n')

plt.rcParams['figure.figsize'] = (11,7)

ax = sns.scatterplot(x="Economy", y="HappinessScore", hue="Country" , data=fe_La)
ax.legend(bbox_to_anchor=(1.30, 1.0));
# Out:
# Gráfico de Economía/Happiness Score por País

# %%
print('Ranking de Países más felices, Región: Latin America and Caribbean \n')
reg=['Latin America and Caribbean']

ordenFelicidad=felicidad[felicidad.Region.isin(reg)]
ordenFelicidad.sort_values(by='HappinessScore',ascending=False).head(10)
# Out:
# Ranking de Países más felices, Región: Latin America and Caribbean
#         Country                       Region  HappinessRank  HappinessScore  \
# 13   Costa Rica  Latin America and Caribbean             14           7.087
# 14  Puerto Rico  Latin America and Caribbean             15           7.039
# 16       Brazil  Latin America and Caribbean             17           6.952
# 20       Mexico  Latin America and Caribbean             21           6.778
# 23        Chile  Latin America and Caribbean             24           6.705
# 24       Panama  Latin America and Caribbean             25           6.701
# 25    Argentina  Latin America and Caribbean             26           6.650
# 28      Uruguay  Latin America and Caribbean             29           6.545
# 30     Colombia  Latin America and Caribbean             31           6.481
# 38    Guatemala  Latin America and Caribbean             39           6.324
#
#     Lower Confidence Interval  Upper Confidence Interval    Economy  \
# 13                      6.999                      7.175  106.87900
# 14                      6.794                      7.284  135.94300
# 16                      6.875                      7.029  108.75400
# 20                      6.680                      6.876  111.50800
# 23                      6.615                      6.795   12.16700
# 24                      6.601                      6.801  118.30600
# 25                      6.560                      6.740  115.13700
# 28                      6.456                      6.634  118.15700
# 30                      6.384                      6.578  103.03200
# 38                      6.213                      6.435    0.83454
#
#        Family   Health  Freedom  Trust (Government Corruption)  Generosity  \
# 13  102.15200  0.76146  0.55225                        0.10547     0.22553
# 14  108.11300  0.77758  0.46823                        0.12275     0.22202
# 16  103.93800  0.61415  0.40425                        0.14166     0.15776
# 20    0.71460  0.71143  0.37709                        0.18355     0.11735
# 23    0.90587  0.81883  0.37789                        0.11451     0.31595
# 24    0.98912  0.70835  0.48927                        0.08423     0.24180
# 25  106.61200  0.69711  0.42284                        0.07296     0.10989
# 28  103.14300  0.72183  0.54388                        0.21394     0.18056
# 30  102.16900  0.59659  0.44735                        0.05399     0.15626
# 38    0.87119  0.54039  0.50379                        0.08701     0.28808
#
#     Dystopia Residual
# 13            335.168
# 14             30.076
# 16            350.733
# 20            355.906
# 23            295.505
# 24            300.559
# 25            312.985
# 28            267.139
# 30            317.471
# 38            319.863

# %%
print('Ranking de Felicidad de países con la economía más baja \n')
economiaBaja=felicidad[felicidad.Economy<5 & felicidad.Region.isin(reg)]
economiaBaja.sort_values(by='HappinessScore',ascending=False).head(10)
# Out:
# Ranking de Felicidad de países con la economía más baja
#          Country                       Region  HappinessRank  HappinessScore  \
# 38     Guatemala  Latin America and Caribbean             39           6.324
# 45   El Salvador  Latin America and Caribbean             46           6.068
# 47     Nicaragua  Latin America and Caribbean             48           5.992
# 50       Ecuador  Latin America and Caribbean             51           5.976
# 51        Belize  Latin America and Caribbean             52           5.956
# 58       Bolivia  Latin America and Caribbean             59           5.822
# 63          Peru  Latin America and Caribbean             64           5.743
# 69      Paraguay  Latin America and Caribbean             70           5.538
# 72       Jamaica  Latin America and Caribbean             73           5.510
# 103     Honduras  Latin America and Caribbean            104           4.871
#
#      Lower Confidence Interval  Upper Confidence Interval  Economy     Family  \
# 38                       6.213                      6.435  0.83454    0.87119
# 45                       5.967                      6.169  0.87370    0.80975
# 47                       5.877                      6.107  0.69384    0.89521
# 50                       5.880                      6.072  0.97306    0.85974
# 51                       5.710                      6.202  0.87616    0.68655
# 58                       5.740                      5.904  0.79422    0.83779
# 63                       5.647                      5.839  0.99602    0.81255
# 69                       5.453                      5.623  0.89373  111.11100
# 72                       5.315                      5.705  0.89333    0.96372
# 103                      4.750                      4.992  0.69429    0.75596
#
#       Health  Freedom  Trust (Government Corruption)  Generosity  \
# 38   0.54039  0.50379                        0.08701     0.28808
# 45   0.59600  0.37269                        0.10613     0.08877
# 47   0.65213  0.46582                        0.16292     0.29773
# 50   0.68613  0.40270                        0.18037     0.10074
# 51   0.45569  0.51231                        0.10771     0.23684
# 58   0.46970  0.50961                        0.07746     0.21698
# 63   0.62994  0.37502                        0.05292     0.14527
# 69   0.58295  0.46235                        0.07396     0.25296
# 72   0.59469  0.43597                        0.04294     0.22245
# 103  0.58383  0.26755                        0.06906     0.20440
#
#      Dystopia Residual
# 38             319.863
# 45             322.134
# 47             282.428
# 50             277.366
# 51             308.039
# 58             291.635
# 63             273.117
# 69             216.091
# 72             235.682
# 103            229.551

# %%
print('Gráfico de HS/Economía de países con baja Economía \n')
ax = sns.scatterplot(x="Economy", y="HappinessScore", hue="Country" , data=economiaBaja)
ax.legend(loc='lower right');
# Out:
# Gráfico de HS/Economía de países con baja Economía
